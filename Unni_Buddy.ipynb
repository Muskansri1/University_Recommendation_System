# %%
import tweepy #Library required for Twitter API
import csv
import pandas as pd
import os
import pandas as pd
import numpy as np

#!pip install wget
import wget
#import mysql-connector as sql

# %%
pip install PyMySQL
# Out:
# Requirement already satisfied: PyMySQL in c:\users\lenovo\anaconda3\lib\site-packages (1.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql

# %%
consumer_key="iIpARRXWJNQBSKaussghVotpp"  #API key
consumer_secret="QGSDxQxoCI28EywSDrmqYzlHdeD1Qok1p9YCB0sBDHZgv0Zui9"  # API Key Secret
access_token="1590179103881109504-7kJQ6y8jcNNEzbbTfJrZRHdAG11qM5"
access_token_secret="M8k3kgD4ngav5328JMKgxmaIk1KXI82EyrgWOVz7Ic4em"

# %%
tweets =pd.DataFrame(columns=["user_id","twitter_handle","user_name","profile_image_url","tweet_description","friends_count","followers_count","user_account_created"])
tweets_account =pd.DataFrame(columns=["user_id","twitter_handle"])

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
outtweets_all =[] #list to store all tweets data

# %%
for tweets in tweepy.Cursor(api.search_tweets,q="#GRE",count=100, #The q variable holds the hashtag 
                           lang="en",
                           since="2017-04-19").items():
    if(tweets.entities.get('media',[])) : #This condition appends only those tweets to the list which have image URL's
        media = tweets.entities.get('media')
        outtweets_all.append([tweets.id_str,tweets.user.id_str,tweets.user.name,tweets.user.screen_name,tweets.user.profile_image_url_https,tweets.user.description,tweets.user.friends_count,tweets.user.followers_count,tweets.user.created_at,tweets.text,tweets.created_at,tweets.favorite_count,tweets.entities['hashtags'],tweets.entities['user_mentions']])
print(outtweets_all)
# Out:
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# [['1591124542772359168', '1280010512709763072', 'IridesMoon', 'IridesMoon', 'https://pbs.twimg.com/profile_images/1280035484589154310/KoHnriVu_normal.jpg', '', 770, 39, datetime.datetime(2020, 7, 6, 5, 27, 53, tzinfo=datetime.timezone.utc), 'RT @yitanran: Using oak gall ink #gre https://t.co/nOBvrq1D4r', datetime.datetime(2022, 11, 11, 17, 43, 47, tzinfo=datetime.timezone.utc), 0, [{'text': 'gre', 'indices': [33, 37]}], [{'screen_name': 'yitanran', 'name': 'Ran/一滩然', 'id': 1239202419352846339, 'id_str': '1239202419352846339', 'indices': [3, 12]}]], ['1590684980271026177', '52135189', 'Jamboree Education', 'JamboreeEdu', 'https://pbs.twimg.com/profile_images/1583799057646235648/o7pFt57n_normal.jpg', '🥇 India’s Leading Institute for All Study Abroad Test Prep and Admissions Counselling Services\n👨🏻\u200d🎓 Delivering High Scores & Top Admits Since 1993', 374, 720, datetime.datetime(2009, 6, 29, 18, 8, 25, tzinfo=datetime.timezone.utc), 'Jamboree-ites doing us proud!\n#GRE #topacheivers https://t.co/rR4pSElj3m', datetime.datetime(2022, 11, 10, 12, 37, 7, tzinfo=datetime.timezone.utc), 0, [{'text': 'GRE', 'indices': [30, 34]}, {'text': 'topacheivers', 'indices': [35, 48]}], []], ['1590434258245816321', '164291336', 'Kaplan Grad Prep', 'KaplanGradPrep', 'https://pbs.twimg.com/profile_images/1542900680616284163/N-AJ7Aos_normal.jpg', 'Welcome to our pre-grad community! Need help with GRE prep? DM us M-Thurs. 9am-10pm, Fri. 9am-9pm, Sat. 9am-6pm (all EST). Or call 1-800-KAP-TEST.', 50, 14950, datetime.datetime(2010, 7, 8, 14, 23, 24, tzinfo=datetime.timezone.utc), "Make sure you've read and reread what you're actually supposed to answer for each question! #GRE #GRETestTips https://t.co/tHUH4SlRrK", datetime.datetime(2022, 11, 9, 20, 0, 50, tzinfo=datetime.timezone.utc), 0, [{'text': 'GRE', 'indices': [92, 96]}, {'text': 'GRETestTips', 'indices': [97, 109]}], []], ['1588847655526215680', '1571278115137114112', 'Moth(derogatory) 🌿 in my LMK / JTTW era 🍑🥭', 'LucifuRRgous', 'https://pbs.twimg.com/profile_images/1583569236303269915/jeaU3bkv_normal.jpg', "@_Lucifugous but furry · Andre/Fern/Moth · Dae/Daem · 🏳\u200d⚧🏳\u200d🌈 · 29 · 80hd &'tism club · OCs in moments! ⚡ RARELY 🔞 tagged as #lucifursins (artistic nudes)", 193, 101, datetime.datetime(2022, 9, 17, 23, 21, 45, tzinfo=datetime.timezone.utc), 'RT @yitanran: Using oak gall ink #gre https://t.co/nOBvrq1D4r', datetime.datetime(2022, 11, 5, 10, 56, 15, tzinfo=datetime.timezone.utc), 0, [{'text': 'gre', 'indices': [33, 37]}], [{'screen_name': 'yitanran', 'name': 'Ran/一滩然', 'id': 1239202419352846339, 'id_str': '1239202419352846339', 'indices': [3, 12]}]]]

# %%
tweetdf_all = pd.DataFrame(outtweets_all,columns = ["tweet_id","user_id","user_name","twitter_handle","profile_image_url","tweet_description","friends_count","followers_count","user_account_created","tweet_text","created_at","tweet_likes","tags",'target_user'])
tweetdf_all.to_csv(r'C:\\Users\\Lenovo\\Downloads\\Twitter_Data\\GRE_data.csv')
tweetdf_all
# Out:
#               tweet_id              user_id  \
# 0  1591124542772359168  1280010512709763072
# 1  1590684980271026177             52135189
# 2  1590434258245816321            164291336
# 3  1588847655526215680  1571278115137114112
#
#                                     user_name  twitter_handle  \
# 0                                  IridesMoon      IridesMoon
# 1                          Jamboree Education     JamboreeEdu
# 2                            Kaplan Grad Prep  KaplanGradPrep
# 3  Moth(derogatory) 🌿 in my LMK / JTTW era 🍑🥭    LucifuRRgous
#
#                                    profile_image_url  \
# 0  https://pbs.twimg.com/profile_images/128003548...
# 1  https://pbs.twimg.com/profile_images/158379905...
# 2  https://pbs.twimg.com/profile_images/154290068...
# 3  https://pbs.twimg.com/profile_images/158356923...
#
#                                    tweet_description  friends_count  \
# 0                                                               770
# 1  🥇 India’s Leading Institute for All Study Abro...            374
# 2  Welcome to our pre-grad community! Need help w...             50
# 3  @_Lucifugous but furry · Andre/Fern/Moth · Dae...            193
#
#    followers_count      user_account_created  \
# 0               39 2020-07-06 05:27:53+00:00
# 1              720 2009-06-29 18:08:25+00:00
# 2            14950 2010-07-08 14:23:24+00:00
# 3              101 2022-09-17 23:21:45+00:00
#
#                                           tweet_text  \
# 0  RT @yitanran: Using oak gall ink #gre https://...
# 1  Jamboree-ites doing us proud!\n#GRE #topacheiv...
# 2  Make sure you've read and reread what you're a...
# 3  RT @yitanran: Using oak gall ink #gre https://...
#
#                  created_at  tweet_likes  \
# 0 2022-11-11 17:43:47+00:00            0
# 1 2022-11-10 12:37:07+00:00            0
# 2 2022-11-09 20:00:50+00:00            0
# 3 2022-11-05 10:56:15+00:00            0
#
#                                                 tags  \
# 0             [{'text': 'gre', 'indices': [33, 37]}]
# 1  [{'text': 'GRE', 'indices': [30, 34]}, {'text'...
# 2  [{'text': 'GRE', 'indices': [92, 96]}, {'text'...
# 3             [{'text': 'gre', 'indices': [33, 37]}]
#
#                                          target_user
# 0  [{'screen_name': 'yitanran', 'name': 'Ran/一滩然'...
# 1                                                 []
# 2                                                 []
# 3  [{'screen_name': 'yitanran', 'name': 'Ran/一滩然'...

# %%
tweetdf_user = tweetdf_all[["user_id","twitter_handle","user_name","profile_image_url","tweet_description","friends_count","followers_count","user_account_created"]]
tweetdf_user = tweetdf_user.drop_duplicates('user_id') #drop duplicates
tweetdf_user
# Out:
#                user_id  twitter_handle  \
# 0  1280010512709763072      IridesMoon
# 1             52135189     JamboreeEdu
# 2            164291336  KaplanGradPrep
# 3  1571278115137114112    LucifuRRgous
#
#                                     user_name  \
# 0                                  IridesMoon
# 1                          Jamboree Education
# 2                            Kaplan Grad Prep
# 3  Moth(derogatory) 🌿 in my LMK / JTTW era 🍑🥭
#
#                                    profile_image_url  \
# 0  https://pbs.twimg.com/profile_images/128003548...
# 1  https://pbs.twimg.com/profile_images/158379905...
# 2  https://pbs.twimg.com/profile_images/154290068...
# 3  https://pbs.twimg.com/profile_images/158356923...
#
#                                    tweet_description  friends_count  \
# 0                                                               770
# 1  🥇 India’s Leading Institute for All Study Abro...            374
# 2  Welcome to our pre-grad community! Need help w...             50
# 3  @_Lucifugous but furry · Andre/Fern/Moth · Dae...            193
#
#    followers_count      user_account_created
# 0               39 2020-07-06 05:27:53+00:00
# 1              720 2009-06-29 18:08:25+00:00
# 2            14950 2010-07-08 14:23:24+00:00
# 3              101 2022-09-17 23:21:45+00:00

# %%
tweetdf_tweet = tweetdf_all[["tweet_id","user_id","tweet_text","created_at","tweet_likes"]]
tweetdf_tweet = tweetdf_tweet.drop_duplicates('tweet_id')
tweetdf_tweet
# Out:
#               tweet_id              user_id  \
# 0  1591124542772359168  1280010512709763072
# 1  1590684980271026177             52135189
# 2  1590434258245816321            164291336
# 3  1588847655526215680  1571278115137114112
#
#                                           tweet_text  \
# 0  RT @yitanran: Using oak gall ink #gre https://...
# 1  Jamboree-ites doing us proud!\n#GRE #topacheiv...
# 2  Make sure you've read and reread what you're a...
# 3  RT @yitanran: Using oak gall ink #gre https://...
#
#                  created_at  tweet_likes
# 0 2022-11-11 17:43:47+00:00            0
# 1 2022-11-10 12:37:07+00:00            0
# 2 2022-11-09 20:00:50+00:00            0
# 3 2022-11-05 10:56:15+00:00            0

# %%
tweetdf_tags = tweetdf_all[["tweet_id","user_id","tags"]]
new_tags =pd.DataFrame(columns=["tweet_id","user_id","tags"])

for i,row in tweetdf_tags.iterrows():
    for values in row['tags']:
        temp=[row['tweet_id'], row['user_id'],values['text']]
        new_tags.loc[len(new_tags)] = temp
new_tags.i=np.arange(1, len(new_tags) + 1)
new_tags['tag_id']=new_tags.i
new_tags=new_tags[['tag_id','user_id','tags','tweet_id']]
new_tags
# Out:
# <ipython-input-11-2c607dcdfbfb>:8: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   new_tags.i=np.arange(1, len(new_tags) + 1)
#    tag_id              user_id          tags             tweet_id
# 0       1  1280010512709763072           gre  1591124542772359168
# 1       2             52135189           GRE  1590684980271026177
# 2       3             52135189  topacheivers  1590684980271026177
# 3       4            164291336           GRE  1590434258245816321
# 4       5            164291336   GRETestTips  1590434258245816321
# 5       6  1571278115137114112           gre  1588847655526215680

# %%
tweetdf_mentions = tweetdf_all[["tweet_id","user_id","target_user"]]
new_mentions =pd.DataFrame(columns=["tweet_id","user_id","target_user"])
            
for i,row in tweetdf_mentions.iterrows():
    if row['target_user']!=None:
        if len(row['target_user'])!=0:
            for values in row['target_user']:
                temp=[row['tweet_id'], row['user_id'],values['screen_name']]
                new_mentions.loc[len(new_mentions)] = temp
new_mentions.i=np.arange(1, len(new_mentions) + 1)
new_mentions['mention_id']=new_mentions.index
new_mentions=new_mentions[['mention_id','tweet_id','user_id','target_user']]
new_mentions
# Out:
# <ipython-input-12-ecf78851d90d>:10: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   new_mentions.i=np.arange(1, len(new_mentions) + 1)
#    mention_id             tweet_id              user_id target_user
# 0           0  1591124542772359168  1280010512709763072    yitanran
# 1           1  1588847655526215680  1571278115137114112    yitanran

# %%
import mysql.connector

# %%
uni_recomm = pymysql.connect(host='localhost', user='root', passwd='RootPassword123', database='university_recommendation')

# %%
cursor= uni_recomm.cursor()

# %%
for i,row in tweetdf_user.iterrows():
    cursor.execute("INSERT INTO User values (%s,%s,%s,%s,%s,%s,%s,%s)", (int(row['user_id']),row['twitter_handle'],row['user_name'],row['profile_image_url'],row['tweet_description'],row['friends_count'],row['followers_count'],row['user_account_created']))
uni_recomm.commit()

cursor.execute("SELECT * from User")
records=cursor.fetchall()

print(records)
uni_recomm.commit()
# Out:
# ((52135189, 'JamboreeEdu', 'Jamboree Education', 'https://pbs.twimg.com/profile_images/1583799057646235648/o7pFt57n_normal.jpg', '🥇 India’s Leading Institute for All Study Abroad Test Prep and Admissions Counselling Services\n👨🏻\u200d🎓 Delivering High Scores & Top Admits Since 1993', 374, 720, datetime.datetime(2009, 6, 29, 14, 8, 25)), (164291336, 'KaplanGradPrep', 'Kaplan Grad Prep', 'https://pbs.twimg.com/profile_images/1542900680616284163/N-AJ7Aos_normal.jpg', 'Welcome to our pre-grad community! Need help with GRE prep? DM us M-Thurs. 9am-10pm, Fri. 9am-9pm, Sat. 9am-6pm (all EST). Or call 1-800-KAP-TEST.', 50, 14950, datetime.datetime(2010, 7, 8, 10, 23, 24)), (1280010512709763072, 'IridesMoon', 'IridesMoon', 'https://pbs.twimg.com/profile_images/1280035484589154310/KoHnriVu_normal.jpg', '', 770, 39, datetime.datetime(2020, 7, 6, 1, 27, 53)), (1571278115137114112, 'LucifuRRgous', 'Moth(derogatory) 🌿 in my LMK / JTTW era 🍑🥭', 'https://pbs.twimg.com/profile_images/1583569236303269915/jeaU3bkv_normal.jpg', "@_Lucifugous but furry · Andre/Fern/Moth · Dae/Daem · 🏳\u200d⚧🏳\u200d🌈 · 29 · 80hd &'tism club · OCs in moments! ⚡ RARELY 🔞 tagged as #lucifursins (artistic nudes)", 193, 101, datetime.datetime(2022, 9, 17, 19, 21, 45)))

# %%
for i,row in new_tags.iterrows():
    cursor.execute("INSERT INTO Tweet_Tags values (%s,%s,%s,%s)", (int(row['tag_id']),row['user_id'],row['tags'],row['tweet_id']))
uni_recomm.commit()
cursor.execute("SELECT * from Tweet_Tags")
records=cursor.fetchall()
print(records)
uni_recomm.commit()
# Out:
# ((1, 1280010512709763072, 'gre', 1591124542772359168), (2, 52135189, 'GRE', 1590684980271026177), (3, 52135189, 'topacheivers', 1590684980271026177), (4, 164291336, 'GRE', 1590434258245816321), (5, 164291336, 'GRETestTips', 1590434258245816321), (6, 1571278115137114112, 'gre', 1588847655526215680))

# %%
for i,row in new_mentions.iterrows():
    cursor.execute("INSERT INTO Tweet_Mentions values (%s,%s,%s,%s)", (int(row['mention_id']),row['tweet_id'],row['user_id'],row['target_user']))
uni_recomm.commit()
cursor.execute("SELECT * from Tweet_Mentions")
records=cursor.fetchall()
print(records)
uni_recomm.commit()
# Out:
# ((0, 1591124542772359168, 1280010512709763072, 'yitanran'), (1, 1588847655526215680, 1571278115137114112, 'yitanran'))

# %%
for i,row in tweetdf_tweet.iterrows():
    cursor.execute("INSERT INTO Tweets values (%s,%s,%s,%s,%s)", (int(row['tweet_id']),row['user_id'],row['tweet_text'],row['created_at'],row['tweet_likes']))
uni_recomm.commit()
cursor.execute("SELECT * from Tweets")
records=cursor.fetchall()
print(records)
uni_recomm.commit()
# Out:
# ((1588847655526215680, 1571278115137114112, 'RT @yitanran: Using oak gall ink #gre https://t.co/nOBvrq1D4r', datetime.datetime(2022, 11, 5, 6, 56, 15), 0), (1590434258245816321, 164291336, "Make sure you've read and reread what you're actually supposed to answer for each question! #GRE #GRETestTips https://t.co/tHUH4SlRrK", datetime.datetime(2022, 11, 9, 15, 0, 50), 0), (1590684980271026177, 52135189, 'Jamboree-ites doing us proud!\n#GRE #topacheivers https://t.co/rR4pSElj3m', datetime.datetime(2022, 11, 10, 7, 37, 7), 0), (1591124542772359168, 1280010512709763072, 'RT @yitanran: Using oak gall ink #gre https://t.co/nOBvrq1D4r', datetime.datetime(2022, 11, 11, 12, 43, 47), 0))

# %%
for tweets in tweepy.Cursor(api.search_tweets,q="#Toefl",count=100, #The q variable holds the hashtag 
                           lang="en",
                           since="2017-04-19").items():
    if(tweets.entities.get('media',[])) : #This condition appends only those tweets to the list which have image URL's
        media = tweets.entities.get('media')
        outtweets_all.append([tweets.id_str,tweets.user.id_str,tweets.user.name,tweets.user.screen_name,tweets.user.profile_image_url_https,tweets.user.description,tweets.user.friends_count,tweets.user.followers_count,tweets.user.created_at,tweets.text,tweets.created_at,tweets.favorite_count,tweets.entities['hashtags'],tweets.entities['user_mentions']])
print(outtweets_all)
# Out:
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# [['1591124542772359168', '1280010512709763072', 'IridesMoon', 'IridesMoon', 'https://pbs.twimg.com/profile_images/1280035484589154310/KoHnriVu_normal.jpg', '', 770, 39, datetime.datetime(2020, 7, 6, 5, 27, 53, tzinfo=datetime.timezone.utc), 'RT @yitanran: Using oak gall ink #gre https://t.co/nOBvrq1D4r', datetime.datetime(2022, 11, 11, 17, 43, 47, tzinfo=datetime.timezone.utc), 0, [{'text': 'gre', 'indices': [33, 37]}], [{'screen_name': 'yitanran', 'name': 'Ran/一滩然', 'id': 1239202419352846339, 'id_str': '1239202419352846339', 'indices': [3, 12]}]], ['1590684980271026177', '52135189', 'Jamboree Education', 'JamboreeEdu', 'https://pbs.twimg.com/profile_images/1583799057646235648/o7pFt57n_normal.jpg', '🥇 India’s Leading Institute for All Study Abroad Test Prep and Admissions Counselling Services\n👨🏻\u200d🎓 Delivering High Scores & Top Admits Since 1993', 374, 720, datetime.datetime(2009, 6, 29, 18, 8, 25, tzinfo=datetime.timezone.utc), 'Jamboree-ites doing us proud!\n#GRE #topacheivers https://t.co/rR4pSElj3m', datetime.datetime(2022, 11, 10, 12, 37, 7, tzinfo=datetime.timezone.utc), 0, [{'text': 'GRE', 'indices': [30, 34]}, {'text': 'topacheivers', 'indices': [35, 48]}], []], ['1590434258245816321', '164291336', 'Kaplan Grad Prep', 'KaplanGradPrep', 'https://pbs.twimg.com/profile_images/1542900680616284163/N-AJ7Aos_normal.jpg', 'Welcome to our pre-grad community! Need help with GRE prep? DM us M-Thurs. 9am-10pm, Fri. 9am-9pm, Sat. 9am-6pm (all EST). Or call 1-800-KAP-TEST.', 50, 14950, datetime.datetime(2010, 7, 8, 14, 23, 24, tzinfo=datetime.timezone.utc), "Make sure you've read and reread what you're actually supposed to answer for each question! #GRE #GRETestTips https://t.co/tHUH4SlRrK", datetime.datetime(2022, 11, 9, 20, 0, 50, tzinfo=datetime.timezone.utc), 0, [{'text': 'GRE', 'indices': [92, 96]}, {'text': 'GRETestTips', 'indices': [97, 109]}], []], ['1588847655526215680', '1571278115137114112', 'Moth(derogatory) 🌿 in my LMK / JTTW era 🍑🥭', 'LucifuRRgous', 'https://pbs.twimg.com/profile_images/1583569236303269915/jeaU3bkv_normal.jpg', "@_Lucifugous but furry · Andre/Fern/Moth · Dae/Daem · 🏳\u200d⚧🏳\u200d🌈 · 29 · 80hd &'tism club · OCs in moments! ⚡ RARELY 🔞 tagged as #lucifursins (artistic nudes)", 193, 101, datetime.datetime(2022, 9, 17, 23, 21, 45, tzinfo=datetime.timezone.utc), 'RT @yitanran: Using oak gall ink #gre https://t.co/nOBvrq1D4r', datetime.datetime(2022, 11, 5, 10, 56, 15, tzinfo=datetime.timezone.utc), 0, [{'text': 'gre', 'indices': [33, 37]}], [{'screen_name': 'yitanran', 'name': 'Ran/一滩然', 'id': 1239202419352846339, 'id_str': '1239202419352846339', 'indices': [3, 12]}]], ['1591950090226524161', '1217266292144537600', 'Zuhriyati Jannah', 'ZuhriyatiJ', 'https://pbs.twimg.com/profile_images/1312058045652889602/oVwwELZr_normal.jpg', '', 134, 47, datetime.datetime(2020, 1, 15, 2, 5, 20, tzinfo=datetime.timezone.utc), 'RT @Next____Level: 📗✏️𝗚𝗿𝗮𝗺𝗺𝗮𝗿 𝗖𝗵𝗲𝗰𝗸 ✏️📗\n\n#ingles  #ESL #toeic #twinglish  #english #toefl https://t.co/WWEbxE4aA7', datetime.datetime(2022, 11, 14, 0, 24, 13, tzinfo=datetime.timezone.utc), 0, [{'text': 'ingles', 'indices': [41, 48]}, {'text': 'ESL', 'indices': [50, 54]}, {'text': 'toeic', 'indices': [55, 61]}, {'text': 'twinglish', 'indices': [62, 72]}, {'text': 'english', 'indices': [74, 82]}, {'text': 'toefl', 'indices': [83, 89]}], [{'screen_name': 'Next____Level', 'name': 'Next Level English 🇬🇧', 'id': 1316297102939521024, 'id_str': '1316297102939521024', 'indices': [3, 17]}]], ['1591948924507815938', '1217266292144537600', 'Zuhriyati Jannah', 'ZuhriyatiJ', 'https://pbs.twimg.com/profile_images/1312058045652889602/oVwwELZr_normal.jpg', '', 134, 47, datetime.datetime(2020, 1, 15, 2, 5, 20, tzinfo=datetime.timezone.utc), 'RT @Next____Level: 📗✏️𝗚𝗿𝗮𝗺𝗺𝗮𝗿 𝗖𝗵𝗲𝗰𝗸 ✏️📗\n\n#ingles  #ESL #toeic #twinglish  #english #toefl https://t.co/oryFE00K0z', datetime.datetime(2022, 11, 14, 0, 19, 35, tzinfo=datetime.timezone.utc), 0, [{'text': 'ingles', 'indices': [41, 48]}, {'text': 'ESL', 'indices': [50, 54]}, ...

# %%
tweetdf_all = pd.DataFrame(outtweets_all,columns = ["tweet_id","user_id","user_name","twitter_handle","profile_image_url","tweet_description","friends_count","followers_count","user_account_created","tweet_text","created_at","tweet_likes","tags",'target_user'])
tweetdf_all.to_csv(r'C:\\Users\\Lenovo\\Downloads\\Twitter_Data\\Toefl_data.csv')
tweetdf_all
# Out:
#                 tweet_id              user_id  \
# 0    1591124542772359168  1280010512709763072
# 1    1590684980271026177             52135189
# 2    1590434258245816321            164291336
# 3    1588847655526215680  1571278115137114112
# 4    1591950090226524161  1217266292144537600
# ..                   ...                  ...
# 237  1590092301233160192  1080157707242561536
# 238  1589810806753218562  1410523769781690369
# 239  1589482810200539136            370900070
# 240  1589165764690718720  1587256630902919168
# 241  1588803822792896513             82618974
#
#                                       user_name   twitter_handle  \
# 0                                    IridesMoon       IridesMoon
# 1                            Jamboree Education      JamboreeEdu
# 2                              Kaplan Grad Prep   KaplanGradPrep
# 3    Moth(derogatory) 🌿 in my LMK / JTTW era 🍑🥭     LucifuRRgous
# 4                              Zuhriyati Jannah       ZuhriyatiJ
# ..                                          ...              ...
# 237                     EnglishLanguageTestPrep    language_prep
# 238               Joki Tugas & TOEFL Specialist  toeflspecialist
# 239                         Hot English Dergisi     hotenglishtr
# 3               [{'text': 'gre', 'indices': [33, 37]}]
# 4    [{'text': 'ingles', 'indices': [41, 48]}, {'te...
# ..                                                 ...
# 237             [{'text': 'TOEFL', 'indices': [3, 9]}]
# 238  [{'text': 'TOEFL', 'indices': [12, 18]}, {'tex...
# 239  [{'text': 'hotenglishtr', 'indices': [27, 40]}...
# 240  [{'text': 'toefl', 'indices': [83, 89]}, {'tex...
# 241  [{'text': 'learnenglish', 'indices': [17, 30]}...
#
#                                            target_user
# 0    [{'screen_name': 'yitanran', 'name': 'Ran/一滩然'...
# 1                                                   []
# 2                                                   []
# 3    [{'screen_name': 'yitanran', 'name': 'Ran/一滩然'...
# 4    [{'screen_name': 'Next____Level', 'name': 'Nex...
# ..                                                 ...
# 237                                                 []
# 238                                                 []
# 239                                                 []
# 240                                                 []
# 241                                                 []
#
# [242 rows x 14 columns]

# %%
tweetdf_user = tweetdf_all[["user_id","twitter_handle","user_name","profile_image_url","tweet_description","friends_count","followers_count","user_account_created"]]
tweetdf_user = tweetdf_user.drop_duplicates('user_id') #drop duplicates
tweetdf_user
# Out:
#                  user_id   twitter_handle  \
# 0    1280010512709763072       IridesMoon
# 1               52135189      JamboreeEdu
# 2              164291336   KaplanGradPrep
# 3    1571278115137114112     LucifuRRgous
# 4    1217266292144537600       ZuhriyatiJ
# ..                   ...              ...
# 232            101952535         sahil6db
# 236  1080157707242561536    language_prep
# 238  1410523769781690369  toeflspecialist
# 240  1587256630902919168     Jumpei_Ishii
# 241             82618974      shaktisuman
#
#                                       user_name  \
# 0                                    IridesMoon
# 1                            Jamboree Education
# 2                              Kaplan Grad Prep
# 3    Moth(derogatory) 🌿 in my LMK / JTTW era 🍑🥭
# 4                              Zuhriyati Jannah
# ..                                          ...
# 232                       ⁦⁦🇵🇰⁩ FAROOQ R. M.🌾🌱🪴
# 236                     EnglishLanguageTestPrep
# 238               Joki Tugas & TOEFL Specialist
# 240                                Jumpei Ishii
# 241                                Shakti Suman
#
#                                      profile_image_url  \
# 0    https://pbs.twimg.com/profile_images/128003548...
# 1    https://pbs.twimg.com/profile_images/158379905...
# 2    https://pbs.twimg.com/profile_images/154290068...
# 3    https://pbs.twimg.com/profile_images/158356923...
# 4    https://pbs.twimg.com/profile_images/131205804...
# ..                                                 ...
# 232  https://pbs.twimg.com/profile_images/154488379...
# 236  https://pbs.twimg.com/profile_images/108015842...
# 238  https://pbs.twimg.com/profile_images/155878656...
# 240  https://pbs.twimg.com/profile_images/158725793...
# 241  https://abs.twimg.com/sticky/default_profile_i...
#
#                                      tweet_description  friends_count  \
# 0                                                                 770
# 1    🥇 India’s Leading Institute for All Study Abro...            374
# 2    Welcome to our pre-grad community! Need help w...             50
# 3    @_Lucifugous but furry · Andre/Fern/Moth · Dae...            193
# 4                                                                 134
# ..                                                 ...            ...
# 232  ‏میں اپنے خواب سے کٹ کے جیوں تو\nمیرے خدا اجاڑ...            695
# 236  Professor Winn helps his students achieve care...            173
# 238  TOEFL ITP, IELTS, TPA Bappenas.               ...            207
# 240  Pitching Coach/Recruiting Coordinator for @Gxa...            990
# 241                                                                99
#
#      followers_count      user_account_created
# 0                 39 2020-07-06 05:27:53+00:00
# 1                720 2009-06-29 18:08:25+00:00
# 2              14950 2010-07-08 14:23:24+00:00
# 3                101 2022-09-17 23:21:45+00:00
# 4                 47 2020-01-15 02:05:20+00:00
# ..               ...                       ...
# 232              598 2010-01-05 04:10:37+00:00
# 236              148 2019-01-01 17:44:00+00:00
# 238              190 2021-07-01 09:00:53+00:00
# 240              234 2022-11-01 01:34:42+00:00
# 241               37 2009-10-15 13:38:37+00:00
#
# [177 rows x 8 columns]

# %%
tweetdf_tweet = tweetdf_all[["tweet_id","user_id","tweet_text","created_at","tweet_likes"]]
tweetdf_tweet = tweetdf_tweet.drop_duplicates('tweet_id')
tweetdf_tweet
# Out:
#                 tweet_id              user_id  \
# 0    1591124542772359168  1280010512709763072
# 1    1590684980271026177             52135189
# 2    1590434258245816321            164291336
# 3    1588847655526215680  1571278115137114112
# 4    1591950090226524161  1217266292144537600
# ..                   ...                  ...
# 237  1590092301233160192  1080157707242561536
# 238  1589810806753218562  1410523769781690369
# 239  1589482810200539136            370900070
# 240  1589165764690718720  1587256630902919168
# 241  1588803822792896513             82618974
#
#                                             tweet_text  \
# 0    RT @yitanran: Using oak gall ink #gre https://...
# 1    Jamboree-ites doing us proud!\n#GRE #topacheiv...
# 2    Make sure you've read and reread what you're a...
# 3    RT @yitanran: Using oak gall ink #gre https://...
# 4    RT @Next____Level: 📗✏️𝗚𝗿𝗮𝗺𝗺𝗮𝗿 𝗖𝗵𝗲𝗰𝗸 ✏️📗\n\n#in...
# ..                                                 ...
# 237  20 #TOEFL Tips | EnglishClub https://t.co/XsI8...
# 238  testi day \n\n#TOEFL \n#TOEFLITP https://t.co/...
# 239  WAYS TO SAY "I UNDERSTAND" #hotenglishtr #hote...
# 240  Just another day to improve my players English...
# 241  Word of the day  #learnenglish #wordoftheday #...
#
#                    created_at  tweet_likes
# 0   2022-11-11 17:43:47+00:00            0
# 1   2022-11-10 12:37:07+00:00            0
# 2   2022-11-09 20:00:50+00:00            0
# 3   2022-11-05 10:56:15+00:00            0
# 4   2022-11-14 00:24:13+00:00            0
# ..                        ...          ...
# 237 2022-11-08 21:22:01+00:00            0
# 238 2022-11-08 02:43:28+00:00            0
# 239 2022-11-07 05:00:07+00:00            3
# 240 2022-11-06 08:00:18+00:00            3
# 241 2022-11-05 08:02:04+00:00            0
#
# [242 rows x 5 columns]

# %%
tweetdf_tags = tweetdf_all[["tweet_id","user_id","tags"]]
new_tags =pd.DataFrame(columns=["tweet_id","user_id","tags"])

for i,row in tweetdf_tags.iterrows():
    for values in row['tags']:
        temp=[row['tweet_id'], row['user_id'],values['text']]
        new_tags.loc[len(new_tags)] = temp
new_tags.i=np.arange(1, len(new_tags) + 1)
new_tags['tag_id']=new_tags.i
new_tags=new_tags[['tag_id','user_id','tags','tweet_id']]
new_tags
# Out:
# <ipython-input-25-2c607dcdfbfb>:8: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   new_tags.i=np.arange(1, len(new_tags) + 1)
#       tag_id              user_id                tags             tweet_id
# 0          1  1280010512709763072                 gre  1591124542772359168
# 1          2             52135189                 GRE  1590684980271026177
# 2          3             52135189        topacheivers  1590684980271026177
# 3          4            164291336                 GRE  1590434258245816321
# 4          5            164291336         GRETestTips  1590434258245816321
# ...      ...                  ...                 ...                  ...
# 1406    1407             82618974               ielts  1588803822792896513
# 1407    1408             82618974          vocabulary  1588803822792896513
# 1408    1409             82618974  vocabularybuilding  1588803822792896513
# 1409    1410             82618974                 hfw  1588803822792896513
# 1410    1411             82618974       vocaboftheday  1588803822792896513
#
# [1411 rows x 4 columns]

# %%
tweetdf_mentions = tweetdf_all[["tweet_id","user_id","target_user"]]
new_mentions =pd.DataFrame(columns=["tweet_id","user_id","target_user"])
            
for i,row in tweetdf_mentions.iterrows():
    if row['target_user']!=None:
        if len(row['target_user'])!=0:
            for values in row['target_user']:
                temp=[row['tweet_id'], row['user_id'],values['screen_name']]
                new_mentions.loc[len(new_mentions)] = temp
new_mentions.i=np.arange(1, len(new_mentions) + 1)
new_mentions['mention_id']=new_mentions.index
new_mentions=new_mentions[['mention_id','tweet_id','user_id','target_user']]
new_mentions
# Out:
# <ipython-input-26-ecf78851d90d>:10: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   new_mentions.i=np.arange(1, len(new_mentions) + 1)
#      mention_id             tweet_id              user_id    target_user
# 0             0  1591124542772359168  1280010512709763072       yitanran
# 1             1  1588847655526215680  1571278115137114112       yitanran
# 2             2  1591950090226524161  1217266292144537600  Next____Level
# 3             3  1591948924507815938  1217266292144537600  Next____Level
# 4             4  1591943104353140737  1248601792696315906  Next____Level
# ..          ...                  ...                  ...            ...
# 213         213  1590248627087503360  1557762605816872960  Next____Level
# 214         214  1590245155705323521  1250026850233069568  Next____Level
# 215         215  1590240141095759873            101952535  Next____Level
# 216         216  1590237123046944768           2186291216  Next____Level
# 217         217  1590237121096609792  1478600089744642051  Next____Level
#
# [218 rows x 4 columns]

# %%
for i,row in tweetdf_user.iterrows():
    cursor.execute("INSERT INTO User values (%s,%s,%s,%s,%s,%s,%s,%s)", (int(row['user_id']),row['twitter_handle'],row['user_name'],row['profile_image_url'],row['tweet_description'],row['friends_count'],row['followers_count'],row['user_account_created']))
uni_recomm.commit()

cursor.execute("SELECT * from User")
records=cursor.fetchall()

print(records)
uni_recomm.commit()
# Out:
# ((39029722, 'molavefinds', 'Jessie Torres', 'https://pbs.twimg.com/profile_images/625427488722714624/i0GWF1vE_normal.png', 'My caffeine fix just got co-opted by #TatayDigong & #BBMSARAUniteam #BuildBuildBuild', 3863, 1477, datetime.datetime(2009, 5, 10, 6, 49, 7)), (52135189, 'JamboreeEdu', 'Jamboree Education', 'https://pbs.twimg.com/profile_images/1583799057646235648/o7pFt57n_normal.jpg', '🥇 India’s Leading Institute for All Study Abroad Test Prep and Admissions Counselling Services\n👨🏻\u200d🎓 Delivering High Scores & Top Admits Since 1993', 374, 720, datetime.datetime(2009, 6, 29, 14, 8, 25
# %%
for i,row in tweetdf_tweet.iterrows():
    cursor.execute("INSERT INTO Tweets values (%s,%s,%s,%s,%s)", (int(row['tweet_id']),row['user_id'],row['tweet_text'],row['created_at'],row['tweet_likes']))
uni_recomm.commit()
cursor.execute("SELECT * from Tweets")
records=cursor.fetchall()
print(records)
uni_recomm.commit()
# Out:
# ((1588803822792896513, 82618974, 'Word of the day  #learnenglish #wordoftheday #toefl #ielts #vocabulary #vocabularybuilding #hfw #vocaboftheday https://t.co/GfUNfvdrs3', datetime.datetime(2022, 11, 5, 4, 2, 4), 0), (1588847655526215680, 1571278115137114112, 'RT @yitanran: Using oak gall ink #gre https://t.co/nOBvrq1D4r', datetime.datetime(2022, 11, 5, 6, 56, 15), 0), (1589165764690718720, 1587256630902919168, 'Just another day to improve my players English to be accepted by school this fall💪\n#toefl\n#JapaneseStudentAthletes https://t.co/sAu6gOdZCg', datetime.datetime(2022, 11, 6, 3, 0, 18), 3), (1589482810200539136, 370900070, 'WAYS TO SAY "I UNDERSTAND" #hotenglishtr\xa0#hotenglish\xa0#ingilizce\xa0#english\xa0#dergi #magazine\xa0#TOEFL\xa0#ielts\xa0#yds https://t.co/68sdlWPIi4', datetime.datetime(2022, 11, 7, 0, 0, 7), 3), (1589810806753218562, 1410523769781690369, 'testi day \n\n#TOEFL \n#TOEFLITP https://t.co/Ttk1Hb3hRb', datetime.datetime(2022, 11, 7, 21, 43, 28), 0), (1590092301233160192, 1080157707242561536, '20 #TOEFL Tips | EnglishClub https://t.co/XsI82yIF61 https://t.co/QEaouGC0P8', datetime.datetime(2022, 11, 8, 16, 22, 1), 0), (1590140623050473472, 1080157707242561536, '#TOEFL, #TOEIC, and #IELTS 50 Video #Vocabulary ECourse https://t.co/eIeYLhx9kI #ecourse https://t.co/Le3vdUFUtE', datetime.datetime(2022, 11, 8, 19, 34, 2), 0), (1590233981286596610, 1316297102939521024, '📗✏️𝗚𝗿𝗮𝗺𝗺𝗮𝗿 𝗖𝗵𝗲𝗰𝗸 ✏️📗\n\n#ingles  #ESL #toeic #twinglish  #english #toefl https://t.co/IPnXEFgqaz', datetime.datetime(2022, 11, 9, 1, 45), 641), (1590237121096609792, 1478600089744642051, 'RT @Next____Level: 📗✏️𝗚𝗿𝗮𝗺𝗺𝗮𝗿 𝗖𝗵𝗲𝗰𝗸 ✏️📗\n\n#ingles  #ESL #toeic #twinglish  #english #toefl https://t.co/IPnXEFgqaz', datetime.datetime(2022, 11, 9, 1, 57, 29), 0), (1590237123046944768, 2186291216, 'RT @Next____Level: 📗✏️𝗚𝗿𝗮𝗺𝗺𝗮𝗿 𝗖𝗵𝗲𝗰𝗸 ✏️📗\n\n#ingles  #ESL #toeic #twinglish  #english #toefl https://t.co/IPnXEFgqaz', datetime.datetime(2022, 11, 9, 1, 57, 29), 0), (1590240141095759873, 101952535, 'RT @Next____Level: 📗✏️𝗚𝗿𝗮𝗺𝗺𝗮𝗿 𝗖𝗵𝗲𝗰𝗸 ✏️📗\n\n#ingles  #ESL #toeic #twinglish  #english #toefl https://t.co/IPnXEFgqaz', datetime.datetime(2022, 11, 9, 2, 9, 29), 0), (1590245155705323521, 1250026850233069568, 'RT @Next____Level: 📗✏️𝗚𝗿𝗮𝗺𝗺𝗮𝗿 𝗖𝗵𝗲𝗰𝗸 ✏️📗\n\n#ingles  #ESL #toeic #twinglish  #english #toefl https://t.co/IPnXEFgqaz', datetime.datetime(2022, 11, 9, 2, 29, 25), 0), (1590248627087503360, 1557762605816872960, 'RT @Next____Level: 📗✏️𝗚𝗿𝗮𝗺𝗺𝗮𝗿 𝗖𝗵𝗲𝗰𝗸 ✏️📗\n\n#ingles  #ESL #toeic #twinglish  #english #toefl https://t.co/IPnXEFgqaz', datetime.datetime(2022, 11, 9, 2, 43, 12), 0), (1590248700785434624, 1450595932114874374, 'RT @Next____Level: 📗✏️𝗚𝗿𝗮𝗺𝗺𝗮𝗿 𝗖𝗵𝗲𝗰𝗸 ✏️📗\n\n#ingles  #ESL #toeic #twinglish  #english #toefl https://t.co/IPnXEFgqaz', datetime.datetime(2022, 11, 9, 2, 43, 30), 0), (1590262177998729218, 385840654, 'RT @Next____Level: 📗✏️𝗚𝗿𝗮𝗺𝗺𝗮𝗿 𝗖𝗵𝗲𝗰𝗸 ✏️📗\n\n#ingles  #ESL #toeic #twinglish  #english #toefl https://t.co/IPnXEFgqaz', datetime.datetime(2022, 11, 9, 3, 37, 3), 0), (1590264109026914305, 749955559743451137, 'RT @Next____Level: 📗✏️𝗚𝗿𝗮𝗺𝗺𝗮𝗿 𝗖𝗵𝗲𝗰𝗸 ✏️📗\n\n#ingles  #ESL #toeic #twinglish  #english #toefl https://t.co/IPnXEFgqaz', datetime.datetime(2022, 11, 9, 3, 44, 43), 0), (1590274157937594368, 1425617521969754113, 'RT @Next____Level: 📗✏️𝗚𝗿𝗮𝗺𝗺𝗮𝗿 𝗖𝗵𝗲𝗰𝗸 ✏️📗\n\n#ingles  #ESL #toeic #twinglish  #english #toefl https://t.co/IPnXEFgqaz', datetime.datetime(2022, 11, 9, 4, 24, 39), 0), (1590290749417213952, 1525690921286676481, 'RT @Next____Level: 📗✏️𝗚𝗿𝗮𝗺𝗺𝗮𝗿 𝗖𝗵𝗲𝗰𝗸 ✏️📗\n\n#ingles  #ESL #toeic #twinglish  #english #toefl https://t.co/IPnXEFgqaz', datetime.datetime(2022, 11, 9, 5, 30, 35), 0), (1590291141400080384, 1234501758363127808, 'RT @Next____Level: 📗✏️𝗚𝗿𝗮𝗺𝗺𝗮𝗿 𝗖𝗵𝗲𝗰𝗸 ✏️📗\n\n#ingles  #ESL #toeic #twinglish  #english #toefl https://t.co/IPnXEFgqaz', datetime.datetime(2022, 11, 9, 5, 32, 8), 0), (1590291685623619584, 733644092475838465, 'RT @Next____Level: 📗✏️𝗚𝗿𝗮𝗺𝗺𝗮𝗿 𝗖𝗵𝗲𝗰𝗸 ✏️📗\n\n#ingles  #ESL #toeic #twinglish  #english #toefl https://t.co/IPnXEFgqaz', datetime.datetime(2 ...
